# %%
from numpy import *
import pandas as pd

# %%
df = pd.read_csv('data.csv', sep=',', error_bad_lines=False)

# %%
print len(df)
# Out:
# 600

# %%
print list(df)
# Out:
# ['id', 'age', 'sex', 'region', 'income', 'married', 'children', 'car', 'save_act', 'current_act', 'mortgage', 'pep']

# %%
# Question 1

# %%
print "MinAge: " , min(df['age'])
print "MaxAge: " , max(df['age'])
print "StdAge: " , df['age'].std()
print "AvgAge: " , df['age'].mean()
# Out:
# MinAge:  18
# MaxAge:  67
# StdAge:  14.424947377538029
# AvgAge:  42.395

# %%
print "MinIncome: " , min(df['income'])
print "MaxIncome: " , max(df['income'])
print "StdIncome: " , df['income'].std()
print "AvgIncome: " , df['income'].mean()
# Out:
# MinIncome:  5014.21
# MaxIncome:  63130.1
# StdIncome:  12899.468245630569
# AvgIncome:  27524.031216666666

# %%
print "MinChildren: " , min(df['children'])
print "MaxChildren: " , max(df['children'])
print "StdChildren: " , df['children'].std()
print "AvgChildren: " , df['children'].mean()
# Out:
# MinChildren:  0
# MaxChildren:  3
# StdChildren:  1.0567521456730191
# AvgChildren:  1.0116666666666667

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import numpy as np

# %%
# Question5

# %%
x = df['age'][~np.isnan(df['age'])]
print('age distribution')
# plot histogram 
n, bins, patches = plt.hist(x, 15, normed=1, facecolor='blue')
plt.show()
# Out:
# age distribution

# %%
x = df['income'][~np.isnan(df['income'])]
print('income distribution')
# plot histogram 
n, bins, patches = plt.hist(x, 9, normed=1, facecolor='blue')
plt.show()
# Out:
# income distribution

# %%
sex_groupby = df.groupby('sex')
print "Sex distribution: "
for key, value in sex_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# Sex distribution:
# ( FEMALE , 300 )
# ( MALE , 300 )

# %%
region_groupby = df.groupby('region')
print "Region distribution: "
for key, value in region_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# Region distribution:
# ( INNER_CITY , 269 )
# ( RURAL , 96 )
# ( SUBURBAN , 62 )
# ( TOWN , 173 )

# %%
married_groupby = df.groupby('married')
print "Customer married distribution: "
for key, value in married_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# Customer married distribution:
# ( NO , 204 )
# ( YES , 396 )

# %%
car_groupby = df.groupby('car')
print "Customer owns one or more cars distribution: "
for key, value in car_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# Customer owns one or more cars distribution:
# ( NO , 304 )
# ( YES , 296 )

# %%
savings_groupby = df.groupby('save_act')
print "Customer has savings account distribution: "
for key, value in savings_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# Customer has savings account distribution:
# ( NO , 186 )
# ( YES , 414 )

# %%
current_groupby = df.groupby('current_act')
print "Customer has current checking account distribution: "
for key, value in current_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# Customer has current checking account distribution:
# ( NO , 145 )
# ( YES , 455 )

# %%
mortgage_groupby = df.groupby('mortgage')
print "Mortgage distribution: "
for key, value in mortgage_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# Mortgage distribution:
# ( NO , 391 )
# ( YES , 209 )

# %%
pep_groupby = df.groupby('pep')
print "PEP purchase distribution: "
for key, value in pep_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# PEP purchase distribution:
# ( NO , 326 )
# ( YES , 274 )

# %%
plt.scatter(df['income'], df['age'])
plt.title("Income vs. Age")
plt.xlabel("age")
plt.ylabel("income")
plt.grid(True)
plt.show()

# %%
# Question 4: Yes, Income and Age seem to be positively correlated.

# %%
# Question 3: define bins as 18-40(young), 40-60(mid-aged), 61-67(old)
bins = [18,40,60,67]
group_names=['young','mid-aged','old']
df['agecategories'] = pd.cut(df['age'], bins, labels=group_names)

# %%
df
# Out:
#           id  age     sex      region    income married  children  car  \
# 0    ID12101   48  FEMALE  INNER_CITY  17546.00      NO         1   NO
# 1    ID12102   40    MALE        TOWN  30085.10     YES         3  YES
# 2    ID12103   51  FEMALE  INNER_CITY  16575.40     YES         0  YES
# 3    ID12104   23  FEMALE        TOWN  20375.40     YES         3   NO
# 4    ID12105   57  FEMALE       RURAL  50576.30     YES         0   NO
# 5    ID12106   57  FEMALE        TOWN  37869.60     YES         2   NO
# 6    ID12107   22    MALE       RURAL   8877.07      NO         0   NO
# 7    ID12108   58    MALE        TOWN  24946.60     YES         0  YES
# 8    ID12109   37  FEMALE    SUBURBAN  25304.30     YES         2  YES
# 9    ID12110   54    MALE        TOWN  24212.10     YES         2  YES
# 10   ID12111   66  FEMALE        TOWN  59803.90     YES         0   NO
# 11   ID12112   52  FEMALE  INNER_CITY  26658.80      NO         0  YES
# ...

# %%
df.sort_values('pep')
# Out:
#           id  age     sex      region    income married  children  car  \
# 299  ID12400   24  FEMALE  INNER_CITY  13667.70     YES         0   NO
# 268  ID12369   63  FEMALE        TOWN  34625.20     YES         0  YES
# 478  ID12579   47    MALE        TOWN  23337.20     YES         2   NO
# 480  ID12581   30    MALE       RURAL  11536.20     YES         2   NO
# 263  ID12364   60  FEMALE  INNER_CITY  46358.40     YES         0  YES
# 262  ID12363   40  FEMALE        TOWN  21612.20     YES         0   NO
# 482  ID12583   44    MALE       RURAL  32762.50      NO         0   NO
# 260  ID12361   22    MALE    SUBURBAN  17180.20     YES         0   NO
# 259  ID12360   36    MALE        TOWN  12166.90      NO         0   NO
# 269  ID12370   20    MALE        TOWN  16672.80      NO         3  YES
# 258  ID12359   38  FEMALE        TOWN  21495.60      NO         3   NO
# 256  ID12357   49  FEMALE    SUBURBAN  26097.90      NO         2   NO
# ...

# %%
#Question 2

# %%
pep_df =df.groupby('pep').std()
print pep_df
# Out:
#            age        income  children
# pep
# NO   14.123506  11661.123422  1.195524
# YES  14.327991  13609.613043  0.860571

# %%
pep_df =df.groupby('pep').mean()
print pep_df
# Out:
#            age        income  children
# pep
# NO   40.098160  24900.953374  1.067485
# YES  45.127737  30644.919453  0.945255

# %%
print df.groupby('pep')['age','income','children'].min()
# Out:
#      age   income  children
# pep
# NO    18  5014.21         0
# YES   18  7756.36         0

# %%
print df.groupby('pep')['age','income','children'].max()
# Out:
#      age   income  children
# pep
# NO    67  61554.6         3
# YES   67  63130.1         3

# %%
#computing summaries of categorical data, sorted by pep==yes and pep==no

# %%
sexYES_groupby=df[df.pep=='YES'].groupby('sex')
sexNO_groupby=df[df.pep=='NO'].groupby('sex')

# %%
print "SEX DISTRIBUTION: "
print "If customer purchased PEP"
for key, value in sexYES_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# SEX DISTRIBUTION:
# If customer purchased PEP
# ( FEMALE , 130 )
# ( MALE , 144 )

# %%
print "If customer did not purchased PEP"
for key, value in sexNO_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# If customer did not purchased PEP
# ( FEMALE , 170 )
# ( MALE , 156 )

# %%
regionYES_groupby=df[df.pep=='YES'].groupby('region')
regionNO_groupby=df[df.pep=='NO'].groupby('region')

# %%
print "REGION DISTRIBUTION: "
print "If customer purchased PEP"
for key, value in regionYES_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# REGION DISTRIBUTION:
# If customer purchased PEP
# ( INNER_CITY , 123 )
# ( RURAL , 46 )
# ( SUBURBAN , 34 )
# ( TOWN , 71 )

# %%
print "REGION DISTRIBUTION: "
print "If customer didn't purchase PEP"
for key, value in regionNO_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# REGION DISTRIBUTION:
# If customer didn't purchased PEP
# ( INNER_CITY , 146 )
# ( RURAL , 50 )
# ( SUBURBAN , 28 )
# ( TOWN , 102 )

# %%
marriedYES_groupby=df[df.pep=='YES'].groupby('married')
marriedNO_groupby=df[df.pep=='NO'].groupby('married')

# %%
print "MARRIAGE DISTRIBUTION: "
print "If customer purchased PEP"
for key, value in marriedYES_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# MARRIAGE DISTRIBUTION:
# If customer purchased PEP
# ( NO , 120 )
# ( YES , 154 )

# %%
print "MARRIAGE DISTRIBUTION: "
print "If customer didn't purchase PEP"
for key, value in marriedNO_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# MARRIAGE DISTRIBUTION:
# If customer didn't purchase PEP
# ( NO , 84 )
# ( YES , 242 )

# %%
carYES_groupby=df[df.pep=='YES'].groupby('car')
carNO_groupby=df[df.pep=='NO'].groupby('car')

# %%
print "CAR DISTRIBUTION: "
print "If customer purchased PEP"
for key, value in carYES_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# CAR DISTRIBUTION:
# If customer purchased PEP
# ( NO , 136 )
# ( YES , 138 )

# %%
print "CAR DISTRIBUTION: "
print "If customer didn't purchase PEP"
for key, value in carNO_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# CAR DISTRIBUTION:
# If customer didn't purchase PEP
# ( NO , 168 )
# ( YES , 158 )

# %%
saveYES_groupby=df[df.pep=='YES'].groupby('save_act')
saveNO_groupby=df[df.pep=='NO'].groupby('save_act')

# %%
print "SAVINGS ACCOUNT DISTRIBUTION: "
print "If customer purchased PEP"
for key, value in saveYES_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# SAVINGS ACCOUNT DISTRIBUTION:
# If customer purchased PEP
# ( NO , 95 )
# ( YES , 179 )

# %%
print "SAVINGS ACCOUNT DISTRIBUTION: "
print "If customer did not purchase PEP"
for key, value in saveNO_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# SAVINGS ACCOUNT DISTRIBUTION:
# If customer did not purchase PEP
# ( NO , 91 )
# ( YES , 235 )

# %%
currentYES_groupby=df[df.pep=='YES'].groupby('current_act')
currentNO_groupby=df[df.pep=='NO'].groupby('current_act')

# %%
print "CHECKING ACCOUNT DISTRIBUTION: "
print "If customer purchased PEP"
for key, value in currentYES_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# CHECKING ACCOUNT DISTRIBUTION:
# If customer purchased PEP
# ( NO , 63 )
# ( YES , 211 )

# %%
print "CHECKING ACCOUNT DISTRIBUTION: "
print "If customer did not purchase PEP"
for key, value in currentNO_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# CHECKING ACCOUNT DISTRIBUTION:
# If customer did not purchase PEP
# ( NO , 82 )
# ( YES , 244 )

# %%
mortgageYES_groupby=df[df.pep=='YES'].groupby('mortgage')
mortgageNO_groupby=df[df.pep=='NO'].groupby('mortgage')

# %%
print "MORTGAGE DISTRIBUTION: "
print "If customer purchased PEP"
for key, value in mortgageYES_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# MORTGAGE DISTRIBUTION:
# If customer purchased PEP
# ( NO , 182 )
# ( YES , 92 )

# %%
print "MORTGAGE DISTRIBUTION: "
print "If customer did not purchase PEP"
for key, value in mortgageNO_groupby:
    print "(", key, ",",len(value), ")"
# Out:
# MORTGAGE DISTRIBUTION:
# If customer did not purchase PEP
# ( NO , 209 )
# ( YES , 117 )

# %%
#Question2: Unmarried men with higher average income and fewer children tend to be the ones who are most likely to purchase PEP.
